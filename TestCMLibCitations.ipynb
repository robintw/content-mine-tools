# %%
from CMLibrary import *

# %%
res = process_all_articles('mdpi-rs/**', pf_get_citation, doi="10.1016/j.jas.2009.10.011")
res
# Out:
#          date                doi         journal  \
# 0  2016-02-19  10.3390/rs8020157  Remote Sensing
# 1  2016-02-20  10.3390/rs8020162  Remote Sensing
# 2  2016-02-20  10.3390/rs8020163  Remote Sensing
# 3  2016-02-23  10.3390/rs8030164  Remote Sensing
# 4  2016-02-23  10.3390/rs8030165  Remote Sensing
# 5  2016-02-23  10.3390/rs8030166  Remote Sensing
# 6  2016-02-23  10.3390/rs8030167  Remote Sensing
# 7  2016-02-23  10.3390/rs8030168  Remote Sensing
# 8  2016-02-25  10.3390/rs8030169  Remote Sensing
# 9  2016-02-25  10.3390/rs8030170  Remote Sensing
# 10 2016-02-25  10.3390/rs8030171  Remote Sensing
# 11 2016-02-24  10.3390/rs8030172  Remote Sensing
# 12 2016-02-25  10.3390/rs8030173  Remote Sensing
# 13 2016-02-25  10.3390/rs8030174  Remote Sensing
# 14 2016-02-25  10.3390/rs8030175  Remote Sensing
# 15 2016-02-25  10.3390/rs8030176  Remote Sensing
# 16 2016-02-25  10.3390/rs8030177  Remote Sensing
# 17 2016-02-25  10.3390/rs8030178  Remote Sensing
# ...

# %%
for i,s in res.dropna().iterrows():
    print(s['title'])
    print("-" * 80)
    print(s['match_0'])
    print('\n\n')
# Out:
# Frescoed Vaults: Accuracy Controlled Simplified Methodology for Planar Development of Three-Dimensional Textured Models
# --------------------------------------------------------------------------------
# The new approach to softcopy photogrammetry realized by Structure from Motion (SfM) and MVS (Multi-View Stereo) algorithms generates very dense 3D color point clouds quite similar in size to those produced from laser scanning surveys [ 18, 19, 20, 21, **REF**, 23].

# %%
get_all_uses_of_citation("mdpi-rs/http_www.mdpi.com_2072-4292_8_3_239_htm/scholarly.html", "10.1016/j.jas.2009.10.011")
# Out:
# Looking for 10.1016/j.jas.2009.10.011 in mdpi-rs/http_www.mdpi.com_2072-4292_8_3_239_htm/scholarly.html
# ['']
